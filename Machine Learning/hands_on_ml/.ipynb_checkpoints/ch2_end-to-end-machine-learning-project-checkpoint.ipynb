# %% [markdown]
# ![book-cover](https://github.com/seankala/ml_study_group/blob/master/Machine%20Learning/hands_on_ml/images/book_cover.jpg?raw=true)

# %% [markdown]
# # Chapter 2: End-to-End Machine Learning Project
#
# As the title implies, this chapter walks us through a machine learning project from the start to finish. It's very nice in the sense that we get a feel of what a machine learning project in the real life (at least from the author's perspective) may look like, what we need to think about, and what steps we need to take.
#
# I'll be covering each section of the chapter briefly. It's rather long but shouldn't be too much if we keep it short and cover the main points.
#
# I'll keep an appendix of all of the mentioned Python commands/methods used with a link to the corresponding documentation.
#
# ### ※ _Many parts of the book are either not up-to-date or too... "from scratch." I'll skip over those parts due to time constraints, but if interested please feel free to go back and check for yourself_.
#
# <br><br>

# %% [markdown]
# ## Table of Contents
#
# **1. Working with Real Data**
#
# **2. Look at the Big Picture**
#    1. Frame the Problem
#    2. Select a Performance Measure
#    3. Check the Assumptions
#
# **3. Get the Data** $\rightarrow$ _**code**_
#    1. Create the Workspace
#    2. Download the Data
#    3. Take a Quick Look at the Data Structure
#    4. Create a Test Set
#
# **4. Discover and Visualize the Data to Gain Insights** $\rightarrow$ _**code**_
#    1. Visualizing Geographical Data
#    2. Looking for Correlations
#    3. Experimenting with Attribute Combinations
#
# **5. Prepare the Data for Machine Learning Algorithms** $\rightarrow$ _**code**_
#    1. Data Cleaning
#    2. handling Text and Categorical Attributes
#    3. Custom Transformers
#    4. Feature Scaling
#    5. Transformation Pipelines
#
# **6. Select and Train a Model** $\rightarrow$ _**code**_
#    1. Training and Evaluating on the Training Set
#    2. Better Evaluation Using Cross-Validation
#
# **7. Fine-Tune Your Model** $\rightarrow$ _**code**_
#    1. Grid Search
#    2. Randomized Search
#    3. Ensemble Methods
#    4. Analyze the Best Methods and Their Erros
#    5. Evaluate Your System on the Test Set
#
# **8. Launch, Monitor, and Maintain Your System**
#
# **9. Try It Out!**
#
# **10. Exercises**

# %% [markdown]
# # 1. Working With Real Data
#
# #### Rather than always working with artificial datasets (e.g. the ones that people make just for school projects), it's better to work with real-world datasets. Some examples are the famous iris dataset.
#
# ##### I personally think this is much better because there are plenty of real-world datasets that are small and simply enough to use as learning experience.
#
# #### Some popular open data repositories are:
#
# ### 1. Kaggle (https://www.kaggle.com/datasets)
#
# ![Kaggle](https://github.com/seankala/ml_study_group/blob/master/Machine%20Learning/hands_on_ml/images/Kaggle_logo.png?raw=true)
#
# ### 2. UC Irvine Machine Learning Repository (http://mlr.cs.umass.edu/ml/)
#
# ![UC Irvine](https://github.com/seankala/ml_study_group/blob/master/Machine%20Learning/hands_on_ml/images/uci_ml_repo.png?raw=true)
#
# ### 3. Amazon AWS Datasets (https://registry.opendata.aws/)
#
# ![AWS](https://github.com/seankala/ml_study_group/blob/master/Machine%20Learning/hands_on_ml/images/aws.jpg?raw=true)
#
# <br>
#
# ---
#
# <br>
#
# ## This chapter will use the California Housing Prices dataset from the StatLib repository (http://lib.stat.cmu.edu/datasets/) (it's not up-to-date and is from the 1990s).
#
# ![alt-text](https://github.com/seankala/ml_study_group/blob/master/Machine%20Learning/hands_on_ml/images/cali_housing_prices.png?raw=true)
#
# <br>
# <br>

# %% [markdown]
# # 2. Look at the Big Picture
#
# _Background: You're a newly hired data scientist for the Machine Learning Housing Corporation (it's fake). Your job is to use machine learning tactics on the California Housing Prices dataset in order to gain insight from the data._
#
# ## 2-1. Frame the Problem
#
# #### What is our objective? What do we plan to gain? These questions are important because they determine which machine learning algorithms we use, which data cleaning processes we use, etc.
#
# The company's objective is to form a downstream pipeline to determine whether a house is worth investing in or not. Our machine learning component will be one part of a larger data pipeline.
#
# A pipeline (or data pipeline) is basically a sequence of components, where one component's output is fed into the next component as input.
#
# ![pipeline](https://github.com/seankala/ml_study_group/blob/master/Machine%20Learning/hands_on_ml/images/data_pipline_housing.png?raw=true)
#
# #### Knowing this information you have gathered, what would your problem be? Is it a regression problem or a classification probem? Should we use batch learning or online learning?
#
# 1. First of all, we have the labels of the houses. Therefore, we can conclude that it's a _**supervised learning problem**_.
#
# 2. Next, we can deduce that it's a _**regression**_ problem and not a classification problem because we're trying to estimate the (continuous) value of samples rather than (discrete) classes.
#
# 3. Last, we should be fine using a _**batch learning**_ system and not an online one because we're not going to be consistently receiving a flow of data and therefore don't need to frequently update our model.
#
# <br><br>
#
# ## 2-2. Select a Performance Measure
#
# _Next, we have to select a performance measure. This is going to be used to determine how well our model is performing._
#
# Typically, the _**Root Mean Square Error (RMSE)**_ is used as the performance measure. The mathematical equation is as follows:
#
# $$\text{RMSE}(\mathbf{X},\ h) = \sqrt{\frac{1}{m}\sum_{i = 1}^m(h(\vec{x}^{(i)}) - y^{(i)})^2}$$
#
# * $\vec{x}$ or $\mathbf{x}$ $\rightarrow$ one single sample (in this case house)
#   * $\vec{x}^{(3)}$ $\rightarrow$ this means the 3rd sample
# * $\mathbf{X} \rightarrow$ matrix containing all samples $\vec{x}$
# * $m \rightarrow$ number of samples
# * $h \rightarrow$ our system's prediction function (a.k.a. hypothesis)
# * $y^{(i)} \rightarrow$ the label (price in this case) for the $i$th sample
#
# Basically, we're taking the square of the difference between our prediction and the actual price, then dividing it by the total number of samples.
#
# The RMSE is also referred to as the _Euclidean norm_ (i.e. distance formula). It's also called the $\ell_2$ norm ($\Vert\ \Vert_2$ or $\Vert\ \Vert$).
#
# <br>
#
# Another well-known performance measure is the _**Mean Absolute Error (MAE)**_. The math equation is as follows:
#
# $$\text{MAE}(\mathbf{X},\ h) = \frac{1}{m}\sum_{i = 1}^m\bigg|\ h(\vec{x}^{(i)}) - y^{(i)})\ \bigg|$$
#
# The symbols used in the notation are the same as the RMSE. The notable difference here is that we don't square and take the square root, but we simply take the absolute value of the difference between our prediction and the actual value.
#
# The MAE is also called the $\ell_1$ norm ($\Vert\ \Vert_1$).
#
# <br>
#
# In general, the $\ell_k$ norm of a vector $\vec{x}$ containing $n$ elements is defined as:
#
# $$\Vert \vec{x} \Vert_k = (\vert x_1 \vert^k + \vert x_2 \vert^k + \ldots + \vert x_n \vert^k)^{1/k}$$
#
# ### The higher the norm index, the more it focuses on large values and neglects small ones. This is why RMSE is more sensitive to outliers than MAE (because it focuses on large values, it focuses more on points that are further away from the actual label than others).
#
# The fact that the RMSE focuses more on outliers isn't necessarily a bad thing, and the RMSE is actually generally preferred.
#
# <br><br>
#
# ## 2-3. Check the Assumptions
#
# It's always important to keep check of the assumptions that we or others made. For example, what if you find out that your company is actually going to take the prices of the houses and label them as "cheap," "medium," and "expensive?" Then what you have is not a regression problem, but a classification problem. You don't want to find out about this later on down the road.
#
# <br><br><br><br>

# %% [markdown]
# # 3. Get the Data
#
# ## 3-1. Create the Workspace
#
# #### This section starts off with a walkthrough on how to install Python and other necessary modules (e.g. Numpy, Pandas, etc.) It will be assumed that everyone has Python installed. If not, it's not hard to install so please Google "how to install Python."
#
# <br><br>
#
# ## 3-2. Download the Data
#
# You can download the data manually from the official Github repository (https://github.com/ageron/handson-ml/tree/master/datasets) or create a small function that will download the data automatically.
#
# You can also write a Python function to download the data from the web browser. The author asserts that this is better if the data changes regularly and you need to continuously update your system. It's also useful if you're downloading the data on multiple devices. Here's the code to do that:
#
# ```Python
# import os
# import tarfile
# from six.moves import urllib
#
#
# DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
# HOUSING_PATH = os.path.join("datasets", "housing")
# HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"
#
# def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
#     if (not os.path.isdir(housing_path)):
#         os.makedirs(housing_path)
#     else:
#         pass
#
#     tgz_path = os.path.join(housing_path, "housing.tgz")
#     urllib.request.urlretrieve(housing_url, tgz_path)
#     housing_tgz = tarfile.open(tgz_path)
#     housing_tgz.extractall(path=housing_path)
#     housing_tgz.close()
# ```
#
# More details can be found here:
#
# [`os.path.join()`](https://docs.python.org/3/library/os.path.html#os.path.join)
#
# [`os.path.isdir()`](https://docs.python.org/3/library/os.path.html#os.path.isdir)
#
# [`os.makedirs()`](https://docs.python.org/3/library/os.html#os.makedirs)
#
# [`urllib.request.urlretrieve()`](https://docs.python.org/3/library/urllib.request.html#urllib.request.urlretrieve)
#
# [`tarfile.open()`](https://docs.python.org/3/library/tarfile.html#tarfile.open)
#
# [`TarFile.extractall()`](https://docs.python.org/3/library/tarfile.html#tarfile.TarFile.extractall)
#
# [`TarFile.close()`](https://docs.python.org/3/library/tarfile.html#tarfile.TarFile.close)

# %%
import os
import tarfile
from six.moves import urllib


DOWNLOAD_ROOT = "https://raw.githubusercontent.com/ageron/handson-ml/master/"
HOUSING_PATH = os.path.join("datasets", "housing")
HOUSING_URL = DOWNLOAD_ROOT + "datasets/housing/housing.tgz"

def fetch_housing_data(housing_url=HOUSING_URL, housing_path=HOUSING_PATH):
    if (not os.path.isdir(housing_path)):
        print("Directory does not exist. Creating directory...\n")
        os.makedirs(housing_path)
    else:
        print("Directory already exists.\n")
        return
    
    tgz_path = os.path.join(housing_path, "housing.tgz")
    print("tgz_path = {}\n".format(tgz_path))
    urllib.request.urlretrieve(housing_url, tgz_path)
    print("urllib.request.urlretrieve(housing_url, tgz_path) = {}\n".format(urllib.request.urlretrieve(housing_url, tgz_path)))
    housing_tgz = tarfile.open(tgz_path)
    print("housing_tgz = {}\n".format(housing_tgz))
    housing_tgz.extractall(path=housing_path)
    housing_tgz.close()
    
    
fetch_housing_data()
# Out:
# Directory already exists.

# %% [markdown]
# <br>
# ### Running this function will ensure that you have made a directory into your current workspace and you have also downloaded the data.
# <br>
#
# ### Now that we downloaded the data from the Internet, let's load the data into a data structure.
#
# Typically, data are loaded into a [`pandas.DataFrame`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html)
#
# ##### Reference:
#
# [`pandas.DataFrame.info()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)
#
# <br>

# %% [markdown]
# ## 3-3. Take a Quick Look at the Data Structure

# %%
import pandas as pd


def load_housing_data(housing_path=HOUSING_PATH): # Function to load housing data.
    csv_path = os.path.join(housing_path, "housing.csv")
    print("csv_path = {}".format(csv_path))
    return pd.read_csv(csv_path)


housing_data = load_housing_data() # Store housing data into variable housing_data.

print("type(housing_data) = {}".format(type(housing_data)))
print('\n')
housing_data.head()
# Out:
# csv_path = datasets\housing\housing.csv
# type(housing_data) = <class 'pandas.core.frame.DataFrame'>
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# ...

# %%
housing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude             20640 non-null float64
# latitude              20640 non-null float64
# housing_median_age    20640 non-null float64
# total_rooms           20640 non-null float64
# total_bedrooms        20433 non-null float64
# population            20640 non-null float64
# households            20640 non-null float64
# median_income         20640 non-null float64
# median_house_value    20640 non-null float64
# ocean_proximity       20640 non-null object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# #### After using the [`pandas.DataFrame.info()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html) method, we can immediately notice that `total_bedrooms` has some missing values (207 to be exact).
#
# #### There are many methods of handling missing values, but in this chapter we'll only take a look at one which is called mean imputation.
#
# <br>
#
# #### We can also see that all data types are numerical (i.e. `float64`) _except_ for `ocean_proximity`. Data types that are not numerical are called _**categorical**_ and may cause problems for our machine learning system. Again, there are ways to deal with this.
#
# #### We can use the [`pandas.Series.value_counts()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html) method to see how many values each category has.
#
# <br>

# %%
print(housing_data['ocean_proximity'].value_counts())
print()
print("Sum of all attribites = {}".format(sum(housing_data['ocean_proximity'].value_counts())))
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64
#
# Sum of all attribites = 20640

# %%
housing_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %% [markdown]
# ##### Note that the [`pandas.DataFrame.describe()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html) method only shows information for categorical values, so `ocean_proximity` is not included.
#
# <br>
#
# #### Now let's try to plot these values using a histogram using [`pandas.DataFrame.hist()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html)
#
# #### It's important to note that the `hist()` method is not native to Pandas. When we call this function, Pandas is actually calling the [`matplotlib.pyplot.hist()`](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html) method on each Series in the DataFrame. Thus, resulting in $n$ histograms for $n$ columns.
#
# <br>

# %%
# %matplotlib inline
import matplotlib.pyplot as plt


housing_data.hist(bins=50, figsize=(30, 15))
plt.show()

# %% [markdown]
# ### First of all, we can notice a few things. Some of the values for some columns have been "capped." Also, most histograms are tail-heavy.
#
# #### The `median_house_value` is our target variable (i.e. the value we're trying to predict) so the fact that it's capped can cause problems.
#
# <br><br>

# %% [markdown]
# ## 3-4. Create a Test Set
#
# #### In machine learning, we typically have different sets of data within the same dataset. We usually have a training set and a test set (and a cross-validation set). We use the training data to train our model, and the test data to evaluate how well our model is performing.
#
# ##### We want to do this to prevent our system from overfitting.
#
# ##### Usually library functions are used, but here the author wrote his own functions.
#
# <br><br>
#
# ### I'll use both the written function and the library function.

# %%
# Using written function.

import numpy as np


def split_train_test(data, test_ratio):
    shuffled_indices = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled_indices[:test_set_size]
    train_indices = shuffled_indices[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]


train_set, test_set = split_train_test(housing_data, 0.25)
print("len(train_set) = {}".format(len(train_set)))
print("len(test_set) = {}".format(len(test_set)))
print("len(test_set) / len(train_set) = {0:.2f}".format(len(test_set) / len(train_set)))
print("\nlen(train_set) + len(test_set) = {}".format(len(train_set) + len(test_set)))
print("len(data) = {}".format(len(housing_data)))
# Out:
# len(train_set) = 15480
# len(test_set) = 5160
# len(test_set) / len(train_set) = 0.33
#
# len(train_set) + len(test_set) = 20640
# len(data) = 20640

# %%
# Using library.

from sklearn.model_selection import train_test_split


train_set2, test_set2 = train_test_split(housing_data, test_size=0.25, random_state=42)

print("len(train_set2) = {}".format(len(train_set2)))
print("len(test_set2) = {}".format(len(test_set2)))
print("len(test_set2) / len(train_set2) = {0:.2f}".format(len(test_set2) / len(train_set2)))
print("\nlen(train_set2) + len(test_set2) = {}".format(len(train_set2) + len(test_set2)))
print("len(data) = {}".format(len(housing_data)))
# Out:
# len(train_set2) = 15480
# len(test_set2) = 5160
# len(test_set2) / len(train_set2) = 0.33
#
# len(train_set2) + len(test_set2) = 20640
# len(data) = 20640

# %% [markdown]
# <br>
# ### We notice that both methods produce same results.
#
# #### Until now, we used purely random sampling. This is usually okay, but if the sample size is small then we may introduce sampling bias.
#
# ##### For example, when a survey company calls 1,000 people to survey, they don't just randomly select 1,000 people. They try to select the people to represent the entire population.
#
# ### We may want to use a technique called [_stratified sampling_](https://en.wikipedia.org/wiki/Stratified_sampling). The pros and cons are nicely explained [here](https://www.investopedia.com/ask/answers/041615/what-are-advantages-and-disadvantages-stratified-random-sampling.asp).
#
# #### We learn that the median income is a very important attribute in predicting the median housing prices, and so decide to create several _strata_ based on that attribute. After taking a look at the histogram for median income above, we notice that most samples' median incomes are clustered from \$20,000 to \$50,000.
#
# ##### The following code creates a new attribute called `income_category`by dividing the median income by 1.5 and rounding up using [`numpy.ceil()`](https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.ceil.html).
#
# #### Reference:
#
# [`numpy.ceil()`](https://docs.scipy.org/doc/numpy-1.15.1/reference/generated/numpy.ceil.html)
#
# [`pandas.DataFrame.where()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.where.html)
#
# <br>

# %%
import numpy as np


housing_data['income_cat'] = np.ceil(housing_data['median_income'] / 1.5)
housing_data['income_cat'].where(cond=(housing_data['income_cat'] < 5), other=5.0, inplace=True)

# %%
housing_data['income_cat'].hist()
plt.show()

# %% [markdown]
# <br>
# #### After using this technique and creating the different subcategories (i.e. strata) for the income, we can now stratified sampling rather than normal random sampling.
#
# ##### Reference:
#
# [`sklearn.model_selection.StratifiedShuffleSplit`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html)
# <br>

# %%
from sklearn.model_selection import StratifiedShuffleSplit


split = StratifiedShuffleSplit(n_splits=1, test_size=0.25, random_state=42)

for train_index, test_index in split.split(housing_data, housing_data['income_cat']):
    print("train_index = {}".format(train_index))
    print("test_index = {}".format(test_index))
    strat_train_set = housing_data.loc[train_index]
    strat_test_set = housing_data.loc[test_index]
    print()
    
print("len(strat_train_set) = {}".format(len(strat_train_set)))
print("len(strat_test_set) = {}".format(len(strat_test_set)))
print("len(strat_test_set) / len(strat_train_set) = {0:.2f}".format(len(strat_test_set) / len(strat_train_set)))
# Out:
# train_index = [ 2370  7281  2714 ... 17552  3987 10061]
# test_index = [ 4149 18749   782 ...  8076 18267  9944]
#
# len(strat_train_set) = 15480
# len(strat_test_set) = 5160
# len(strat_test_set) / len(strat_train_set) = 0.33

# %% [markdown]
# ### Now that we've performed stratified sampling, let's see if our sampling really is representative of our population.
#
# #### In order to do this, take the proportion of how many of each income category was sampled from the entire population.
#
# ##### Reference
#
# [`pandas.DataFrame.value_counts()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
#
# [`pandas.DataFrame.sort_index()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_index.html)

# %%
# When we compare to the histogram above, we can see whether our stratified sampling worked or not.

strat_test_set['income_cat'].value_counts().sort_index() / len(strat_test_set)
# Out:
# 1.0    0.039922
# 2.0    0.318798
# 3.0    0.350581
# 4.0    0.176357
# 5.0    0.114341
# Name: income_cat, dtype: float64

# %% [markdown]
# ### After we've conducted stratified sampling, we need to remove the `income_cat` column  because it's of no use to us anymore.

# %%
for set_ in (strat_train_set, strat_test_set):
    set_.drop('income_cat', axis=1, inplace=True)
    
print(strat_train_set.describe())

# %% [markdown]
# <br><br>
#
# # 4. Discover and Visualize the Data to Gain Insights
# <br>
#
# ## 4-1. Visualizing Geographical Data
#
# ### Since we have the geographical information (longitude & latitude), we can graph out the points using a scatter plot.
#
# <br>

# %%
# First, make a copy of the data so that we don't modify the original data.
# Simply using assignment to make a copy won't work because that will modify the original as well.

housing_copy = strat_train_set.copy()
housing_copy.plot(kind='scatter', x='longitude', y='latitude')

# %% [markdown]
# ### We can see that the data plotted does indeed look like California, but we can't really tell anything with this kind of plot.
#
# ### In order to gain more insight, we can change the `alpha` keyword argument within the `plot()` function. The `alpha` argument changes with how "thick" or transparent each point is. The smaller the value, the more transparent the points become. Default value is 1.
#
# #### More specifically, the `alpha` value is actually the _**alpha blending value**_, and has to do with something called [alpha compositing](https://en.wikipedia.org/wiki/Alpha_compositing) in computer graphics.

# %%
housing_copy.plot(kind='scatter', x='longitude', y='latitude', alpha=0.01)

# %% [markdown]
# <br>
#
# #### This plot is good, but it still doesn't perform visually as well as we would like, since all it shows us is where the majority of housing data points are. We should change the color map to represent , and also will change the size of each circular point to represent population size.
#
# <br>

# %%
housing_copy.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4,
                  s=(housing_copy['population'] / 100), label='population', figsize=(10, 7),
                  c='median_house_value', cmap=plt.get_cmap('jet'), colorbar=True)

plt.show()

# %% [markdown]
# <br>
#
# ## 4-2. Looking for Correlations
#
# ### Since our dataset is not very large, we can just compute the [Pearson correlation coefficient](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient) between every pair of attributes using the [`pandas.DataFrame.corr()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html) method.
#
# ### Let's first calculate the correlation for each attribute paired up with `median_house_value` and also draw a heatmap matrix to see the correlation of each variable paired with each other variable using [`matplotlib.axes.Axes.matshow()`](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.matshow.html)
#
# #### Reference:
#
# 1. Pearson correlation coefficient:
#
#   * In statistics the Pearson correlation coefficient (PCC or Pearson's r) measures the correlation between two variables. It takes the covariance between the two variables ($\text{Cov}(X,\ Y)$) and divides that by the product of the standard deviations of both variables ($\sqrt{\text{Var}(X)\text{Var}(Y)}$ or $\sigma(X)\sigma(Y)$).
#   * The covariance is computed as follows: $\text{Cov}(X,\ Y) = \text{E}(XY) - \text{E}(X)\text{E}(Y)$
#
#   $$\rho(X,\ Y) = \frac{\text{Cov}(X,\ Y)}{\sigma(X)\sigma(Y)}$$
#
# 2. [`pandas.DataFrame.corr()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
#
# 3. [`matplotlib.axes.Axes.matshow()`](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.matshow.html)

# %%
corr_matrix = housing_copy.corr()
print(corr_matrix.head())
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924580           -0.112000     0.051092
# latitude            -0.924580  1.000000            0.011280    -0.041563
# housing_median_age  -0.112000  0.011280            1.000000    -0.365047
# total_rooms          0.051092 -0.041563           -0.365047     1.000000
# total_bedrooms       0.078457 -0.074295           -0.324281     0.928598
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.078457    0.108745    0.064105      -0.019355
# latitude                 -0.074295   -0.116079   -0.079043      -0.075455
# housing_median_age       -0.324281   -0.297466   -0.305010      -0.111328
# total_rooms               0.928598    0.852779    0.917480       0.198570
# total_bedrooms            1.000000    0.873387    0.979752      -0.012094
#
#                     median_house_value  income_cat
# ...

# %%
# Columns of DataFrame except for categorical value columns.
def housing_heatmap(data):
    columns = data.select_dtypes(exclude='object').columns
    corr_matrix = data.corr()

    fig, ax = plt.subplots(figsize=(8, 8))
    mat = ax.matshow(corr_matrix, cmap='jet')

    ax.set_xticks(range(len(columns)))
    ax.set_yticks(range(len(columns)))
    ax.set_xticklabels(columns)
    ax.set_yticklabels(columns)
    plt.setp(ax.get_xticklabels(), rotation=45, ha='left', rotation_mode='anchor')
    plt.colorbar(mat, fraction=0.045, pad=0.05)

    fig.tight_layout()
    plt.show()
    return None
    
    
def house_value_corr(data=housing_copy):
    corr_matrix = data.corr()
    print("Corr(median_house_value, X)")
    print('-' * 30)
    print(corr_matrix['median_house_value'].sort_values(ascending=False))
    return None
    
    
housing_heatmap(housing_copy)
print('\n')
house_value_corr()
# Out:
# Corr(median_house_value, X)
# ------------------------------
# median_house_value    1.000000
# median_income         0.686591
# income_cat            0.642217
# total_rooms           0.135466
# housing_median_age    0.114116
# households            0.064853
# total_bedrooms        0.047654
# population           -0.027496
# longitude            -0.050832
# latitude             -0.139756
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### We've just drawn a heatmap to annotate the correlation of variables with other variable. If we take a look at just `median_house_value`, we can see that it's very positively correlated with `median_income`, which makes sense.

# %%
corr_matrix['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value    1.000000
# median_income         0.686591
# income_cat            0.642217
# total_rooms           0.135466
# housing_median_age    0.114116
# households            0.064853
# total_bedrooms        0.047654
# population           -0.027496
# longitude            -0.050832
# latitude             -0.139756
# Name: median_house_value, dtype: float64

# %% [markdown]
# <br>
#
# ### You can also use a [scatter matrix](https://en.wikipedia.org/wiki/Scatter_matrix) to visualize the correlation in a more intuitive manner.
#
# #### We have a total of 11 attributes, so that means if we create a scatter matrix with all 11 we'll end up with $11^2 = 121$ plots. That's a bit too much, so we'll just choose the first four attributes that are the most positively correlated with `median_house_value`.
#
# <br>

# %%
from pandas.plotting import scatter_matrix


attributes = corr_matrix['median_house_value'].sort_values(ascending=False).index[0:4]

scatter_matrix(housing_copy[attributes], figsize=(12, 8), alpha=0.1)

plt.show()

# %% [markdown]
# <br>
#
# ### It seems that `median_income` is the most positively correlated with `median_house_value`, so let's take a closer look at that.
#
# <br>

# %%
housing_copy.plot(kind='scatter', x='median_income', y='median_house_value', alpha=0.1)
plt.show()

# %% [markdown]
# <br>
#
# ---
#
# # 4-3. Experimenting with Attribute Combinations
#
# ### We've taken a look at a lot of stuff, but we may also want to consider combining attributes with one another. For example, the `total_rooms` attribute is not very useful in and of itself. What we want to know is how many rooms there are per household. Also, we want to know how many bedrooms there are compared to the total number of rooms, not just how many bedrooms there are.
#
# #### This process can be further called _**feature engineering**_. There are entire books written on this topic and some people go as far as to saying that machine learning is just a matter of how much data you have and how many relevant features you can create.
#
# ### Let's create our new attributes and see the correlation again.
#
# <br>

# %%
housing_copy['rooms_per_household'] = housing_copy['total_rooms'] / housing_copy['households']
housing_copy['bedrooms_per_rooms'] = housing_copy['total_bedrooms'] / housing_copy['total_rooms']
housing_copy['population_per_household'] = housing_copy['population'] / housing_copy['households']

# %%
housing_heatmap(housing_copy)
print('\n')
house_value_corr()
# Out:
# Corr(median_house_value, X)
# ------------------------------
# median_house_value          1.000000
# median_income               0.686591
# income_cat                  0.642217
# rooms_per_household         0.149375
# total_rooms                 0.135466
# housing_median_age          0.114116
# households                  0.064853
# total_bedrooms              0.047654
# population_per_household   -0.021730
# population                 -0.027496
# longitude                  -0.050832
# latitude                   -0.139756
# bedrooms_per_rooms         -0.264596
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### As we can see, our newly made features actually perform pretty well.
#
# <br><br>
#
# ---
#
# # 5. Prepare the Data for Machine Learning Algorithms
#
# ### There are many things that we need to do before using our data for machine learning algorithms. This is called "cleaning" the data. Usually, public datasets that we can access have already been cleaned.
#
# <br>
#
# ### First, we'll separate the `median_house_value` column from the rest of the dataset and use it as our label (true values) to use for predictions.

# %%
housing = strat_train_set.drop('median_house_value', axis=1)
housing_labels = strat_train_set['median_house_value'].copy()

# %%
print('housing.info()')
print('-' * 80)
print(housing.info())

print('\n\n')

print('housing_labels.describe()')
print('-' * 80)
print(housing_labels.describe())
# Out:
# housing.info()
# --------------------------------------------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15480 entries, 2370 to 10061
# Data columns (total 10 columns):
# longitude             15480 non-null float64
# latitude              15480 non-null float64
# housing_median_age    15480 non-null float64
# total_rooms           15480 non-null float64
# total_bedrooms        15331 non-null float64
# population            15480 non-null float64
# households            15480 non-null float64
# median_income         15480 non-null float64
# ocean_proximity       15480 non-null object
# income_cat            15480 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 1.3+ MB
# None
#
#
#
# housing_labels.describe()
# --------------------------------------------------------------------------------
# count     15480.000000
# mean     207176.352390
# std      115696.878035
# min       14999.000000
# 25%      119900.000000
# ...

# %% [markdown]
# <br>
#
# ## 5-1. Data Cleaning
#
# ### This section focuses on cleaning up the missing features that we saw earlier. Most machine learning algorithms cannot work with missing features, so it's important that we take care of these.
#
# ### There are a few ways that we can do this.
#
# #### 1. Get rid of the samples that have missing values (listwise deletion a.k.a. complete-case analysis).
#
# #### 2. Get rid of the whole attribute.
#
# #### 3. Set the missing values to some value (mean, median, regression, etc.).
#
# ### Pandas actually has built-in functions that let us do these operations conveniently: [`pandas.DataFrame.dropna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html), [`pandas.DataFrame.drop()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html), and [`pandas.DataFrame.fillna()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.fillna.html).
#
# #### First of all, let's see which values are missing.

# %%
housing.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        149
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# income_cat              0
# dtype: int64

# %%
'''
Option 1:
housing.dropna(subset=['total_bedrooms'])

Option 2:
housing.drop('total_bedrooms', axis=1)

Option 3:
median = housing['total_bedrooms'].median()
housing['total_bedroom'].fillna(median, inplace=True)
'''

# %% [markdown]
# <br>
#
# ### Scikit-Learn also provides a class to take care of missing values called the [SimpleImputer](http://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html).

# %%
from sklearn.impute import SimpleImputer


imputer = SimpleImputer(strategy='median')

# %%
housing_num = housing.drop('ocean_proximity', axis=1)
imputer.fit(housing_num)
# Out:
# SimpleImputer(copy=True, fill_value=None, missing_values=nan,
#        strategy='median', verbose=0)

# %% [markdown]
# ### Now that we've fit the Imputer to the data, we can call the attribute `imputer.statistics_` in order to get the fill value for each attribute that Imputer has calculated.

# %%
print("Calculated values used to fill in each attribute:")

for num, fill_val in enumerate(imputer.statistics_):
    print("{}: {}".format(housing_num.columns[num], fill_val))
    
print()

print("Actual median values:")

for num, median in enumerate(housing_num.median().values):
    print("{}: {}".format(housing_num.columns[num], median))
# Out:
# Calculated values used to fill in each attribute:
# longitude: -118.52
# latitude: 34.27
# housing_median_age: 29.0
# total_rooms: 2116.0
# total_bedrooms: 431.0
# population: 1162.0
# households: 407.0
# median_income: 3.53635
# income_cat: 3.0
#
# Actual median values:
# longitude: -118.52
# latitude: 34.27
# housing_median_age: 29.0
# total_rooms: 2116.0
# total_bedrooms: 431.0
# population: 1162.0
# households: 407.0
# median_income: 3.53635
# income_cat: 3.0

# %% [markdown]
# ### Now that we've fit the Imputer, we can use this to "transform" the original training data.

# %%
X = imputer.transform(housing_num)

housing_train = pd.DataFrame(X, columns=housing_num.columns)

print(housing_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 9 columns):
# longitude             15480 non-null float64
# latitude              15480 non-null float64
# housing_median_age    15480 non-null float64
# total_rooms           15480 non-null float64
# total_bedrooms        15480 non-null float64
# population            15480 non-null float64
# households            15480 non-null float64
# median_income         15480 non-null float64
# income_cat            15480 non-null float64
# dtypes: float64(9)
# memory usage: 1.1 MB
# None

# %% [markdown]
# <br>
#
# ## 5-2. Handling Text and Categorical Attributes
#
# ### Earlier, we left out `ocean_proximity` because it was a categorical value and not a numerical one. We'll see how we can handle categorical attributes as well.
#
# <br>

# %%
housing_cat = housing['ocean_proximity']

housing_cat.describe()
# Out:
# count         15480
# unique            5
# top       <1H OCEAN
# freq           6816
# Name: ocean_proximity, dtype: object

# %% [markdown]
# <br>
#
# ### Most machine learning algorithms (and computers for that matter) like to work with numbers, so we'll have to change the categorical attributes into numerical ones.
#
# ### There are also a few ways to do this, but this book uses the [`pandas.factorize()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.factorize.html) method.
#
# #### Reference:
#
# https://stackoverflow.com/questions/40336502/want-to-know-the-diff-among-pd-factorize-pd-get-dummies-sklearn-preprocessing
#
# <br>

# %%
housing_cat_encoded, housing_categories = housing_cat.factorize()

print("Newly encoded categories:")
print(housing_cat_encoded[:10])
print()
print("Categories:")
print(housing_categories)
# Out:
# Newly encoded categories:
# [0 1 0 2 0 1 0 1 0 1]
#
# Categories:
# Index(['INLAND', '<1H OCEAN', 'NEAR OCEAN', 'NEAR BAY', 'ISLAND'], dtype='object')

# %% [markdown]
# ### This is much better for computers, but there is still a problem. The machine learning system will assume that closer numbers are related to each other somehow. This will cause bias in the system, and so we need to further encode these into binary values so that this problem does not exist.
#
# ### Further encoding values into binary is called "one-hot encoding" or "one-of-K encoding."
#
# <br>

# %%
from sklearn.preprocessing import OneHotEncoder


encoder = OneHotEncoder()

housing_cat_1hot = encoder.fit_transform(housing_cat_encoded.reshape(-1, 1))
print("type(housing_cat_1hot) = {}".format(type(housing_cat_1hot)))
print()
print("housing_cat_1hot:")
print(housing_cat_1hot)
# Out:
# type(housing_cat_1hot) = <class 'scipy.sparse.csr.csr_matrix'>
#
# housing_cat_1hot:
#   (0, 0)	1.0
#   (1, 1)	1.0
#   (2, 0)	1.0
#   (3, 2)	1.0
#   (4, 0)	1.0
#   (5, 1)	1.0
#   (6, 0)	1.0
#   (7, 1)	1.0
#   (8, 0)	1.0
#   (9, 1)	1.0
#   (10, 3)	1.0
#   (11, 1)	1.0
#   (12, 0)	1.0
#   (13, 0)	1.0
#   (14, 3)	1.0
#   (15, 3)	1.0
#   (16, 0)	1.0
#   (17, 1)	1.0
#   (18, 1)	1.0
#   (19, 0)	1.0
#   (20, 1)	1.0
#   (21, 1)	1.0
#   (22, 0)	1.0
#   (23, 1)	1.0
#   (24, 1)	1.0
#   :	:
#   (15455, 1)	1.0
#   (15456, 0)	1.0
#   (15457, 0)	1.0
#   (15458, 1)	1.0
#   (15459, 1)	1.0
#   (15460, 3)	1.0
#   (15461, 0)	1.0
#   (15462, 0)	1.0
#   (15463, 1)	1.0
#   (15464, 0)	1.0
#   (15465, 1)	1.0
#   (15466, 0)	1.0
#   (15467, 0)	1.0
#   (15468, 0)	1.0
#   (15469, 0)	1.0
#   (15470, 0)	1.0
#   (15471, 0)	1.0
#   (15472, 3)	1.0
#   (15473, 0)	1.0
#   (15474, 0)	1.0
#   (15475, 0)	1.0
#   (15476, 2)	1.0
#   (15477, 1)	1.0
#   (15478, 1)	1.0
#   (15479, 0)	1.0
# ...

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## 5-3. Feature Scaling
#
# ### Feature scaling is scaling all the attribute values to be within the same scale. There are many ways to do this, but the most common ones are _min-max normalization_ and _standardization_.
#
# ##### Here's a great post describing the difference between the two:
# [Stats Stack Exchange - What's the Difference Between Normalization and Standardization?](https://stats.stackexchange.com/questions/10289/whats-the-difference-between-normalization-and-standardization)
#
# ### The ways of performing both are as follows:
#
# #### Normalization:
#
# $$x_\text{new} = \frac{x - \text{min}(x)}{\text{max}(x) - \text{min}(x)}$$
#
# #### Standardization:
#
# $$x_\text{new} = \frac{x - \mu}{\sigma}$$
#
#   * $\mu = \text{E}(x)$
#   * $\sigma = \text{STD}(x) = \sqrt{\text{Var}(x)}$
#
# <br>
#
# ### Scikit-Learn provides the [`sklearn.preprocessing.StandardScaler`](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.StandardScaler.html) class to handle this.
#
# <br>

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# ## 5-4. Transformation Pipelines
#
# ### There are many steps to perform in this whole process, and so Scikit-Learn provides the [`sklearn.pipeline.Pipeline`](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html) class to handle this.
#
# <br>

# %%
from sklearn.base import BaseEstimator, TransformerMixin

rooms_ix, bedrooms_ix, population_ix, household_ix = 3, 4, 5, 6


class CombinedAttributesAdder(BaseEstimator, TransformerMixin):
    
    def __init__(self, add_bedrooms_per_room = True):
        self.add_bedrooms_per_room = add_bedrooms_per_room
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        rooms_per_household = X[:, rooms_ix] / X[:, household_ix]
        
        population_per_household = X[:, population_ix] / X[:, household_ix]
        
        if (self.add_bedrooms_per_room):
            bedrooms_per_room = X[:, bedrooms_ix] / X[:, rooms_ix]
            return np.c_[X, rooms_per_household, population_per_household, bedrooms_per_room]
        else:
            return np.c_[X, rooms_per_household, population_per_household]
        
        
attr_adder = CombinedAttributesAdder(add_bedrooms_per_room=False)
housing_extra_attribs = attr_adder.transform(housing.values)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler


num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler())
])

housing_num_tr = num_pipeline.fit_transform(housing_num)

# %%
from sklearn.base import BaseEstimator, TransformerMixin


class DataFrameSelector(BaseEstimator, TransformerMixin):
    
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
        
    
    def fit(self, X, y=None):
        return self
    
    
    def transform(self, X):
        return X[self.attribute_names].values

# %%
num_attribs = list(housing_num)
cat_attribs = ['ocean_proximity']

num_pipeline = Pipeline([
    ('selector', DataFrameSelector(num_attribs)),
    ('imputer', SimpleImputer(strategy='median')),
    ('attribs_adder', CombinedAttributesAdder()),
    ('std_scaler', StandardScaler())
])

cat_pipeline = Pipeline([
    ('selector', DataFrameSelector(cat_attribs)),
    ('onehot_encoder', OneHotEncoder())
])

# %%
from sklearn.pipeline import FeatureUnion


full_pipeline = FeatureUnion(transformer_list=[
    ('num_pipeline', num_pipeline),
    ('cat_pipeline', cat_pipeline),
])

# %%
housing_prepared = full_pipeline.fit_transform(housing)

# %%
housing_prepared = np.asarray(housing_prepared)
housing_prepared

# %%
'''# Step 1 : Create new meaningful features.
housing['rooms_per_household'] = housing['total_rooms'] / housing['households']
housing['bedrooms_per_rooms'] = housing['total_bedrooms'] / housing['total_rooms']
housing['population_per_household'] = housing['population'] / housing['households']



# Step 2 : Clean the data.
from sklearn.preprocessing import Imputer


imputer = Imputer(strategy='median')

housing['total_bedrooms'] = imputer.fit_transform(housing['total_bedrooms'].values.reshape(-1, 1))
housing['bedrooms_per_rooms'] = imputer.fit_transform(housing['bedrooms_per_rooms'].values.reshape(-1, 1))



# Step 3 : Handle categorical data.
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder


label_enc = LabelEncoder()
onehot_enc = OneHotEncoder()

#housing['ocean_proximity'] = label_enc.fit_transform(housing['ocean_proximity'])
#housing['ocean_proximity'] = onehot_enc.fit_transform(housing['ocean_proximity'].values.reshape(-1, 1))



# Step 4 : Feature Scaling
from sklearn.preprocessing import MinMaxScaler


minmaxscaler = MinMaxScaler()
housing = minmaxscaler.fit_transform(housing)


housing.head()'''

# %% [markdown]
# ### The rest of the section defines custom classes, and we won't be covering those this time. Feel free to take a look if you're interested.
#
# <br>

# %% [markdown]
# <br>
#
# ---
#
# <br>
#
# # 6. Select and Train a Model
#
# ### The steps that we've taken until now are:
#
# #### 1. Get the data and explore it.
#
# #### 2. Get a training and test set.
#
# #### 3. Write transformation pipelines to clean up and prepare your data for ML algorithms automatically.
#
# <br>
#
# ### Now it's time to actually use the data we have to train a ML algorithm.
#
# <br>

# %% [markdown]
# ---
#
# <br>
#
# ## 6-1. Training and Evaluating on the Training Set
#
# ### The hard part of any ML task is the preparation. The training and evaluating is the fun part.
#
# ### We'll first use a simple linear regression model ([`sklearn.linear_model.LinearRegression`](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html).
#
# <br>

# %%
housing.drop('ocean_proximity', axis=1, inplace=True)

# %%
housing.fillna(housing['total_bedrooms'].median(), inplace=True)

print(housing.isna().sum())
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# income_cat            0
# dtype: int64

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(housing, housing_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lin_reg.score(housing, housing_labels)
# Out:
# 0.6359710411265038
