# %% [markdown]
# # ML Study Group
#
# ##### March 4th, 2019 (Monday) 19:00 (GMT+9) @ Bitcoin Center Korea ([Meetup.com link](https://www.meetup.com/ml_study_group/events/259323184/))
#
# ## 1. Review last session and go through the technical details a bit more.
#
# ## 2. Introduction to linear regression.
#
# #### This session we'll be going over some details from last session (_Hands-On ML Chapter 2_) and also some concepts of linear regression. It's assumed that you have Python and the corresponding libraries installed, but if you don't then it shouldn't be hard to set up.
#
# <br>
#
# ![alt-text](https://github.com/seankala/ml_study_group/blob/master/Images/ML/py_logos.png?raw=true)
#
# <br>
#
# ![alt-text](https://github.com/seankala/ml_study_group/blob/master/Images/ML/homl_islr.jpg?raw=true)
#
# <br>
# <br>

# %% [markdown]
# ## List of Methods and Functions Used in Chapter 2
#
# ### [Pandas](https://pandas.pydata.org/)
#
# 1. [**pandas.read_csv**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
#
# 2. [**pandas.DataFrame**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html)
#
# 3. [**pandas.Series**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html)
#
# 4. [**pandas.DataFrame.head**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html)
#
# 5. [**pandas.DataFrame.info**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)
#
# 6. [**pandas.Series.value_counts**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
#
# 7. [**pandas.DataFrame.describe**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html)
#
# 8. [**pandas.DataFrame.hist**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.hist.html)
#
# 9. [**pandas.DataFrame.loc**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
#
# 10. [**pandas.DataFrame.iloc**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.iloc.html)
#
# 11. [**pandas.DataFrame.sort_index**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_index.html)
#
# 12. [**pandas.DataFrame.drop**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html)
#
# 13. [**pandas.DataFrame.corr**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
#
# 14. [**pandas.DataFrame.columns**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html)
#
# 15. [**pandas.plotting.scatter_matrix**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.plotting.scatter_matrix.html)
#
# 16. [**pandas.DataFrame.sort_values**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html)
#
# 17. [**pandas.DataFrame.copy**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html)
#
# 18. [**pandas.DataFrame.dropna**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.dropna.html)
#
# 19. [**pandas.DataFrame.fillna**](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html)
#
# 20. [**pandas.DataFrame.isna**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.isna.html)
#
# 21. [**pandas.DataFrame.sum**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sum.html)
#
# 22. [**pandas.DataFrame.median**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.median.html)
#
# <br>
#
# ### [Matplotlib](https://matplotlib.org/)
#
# 1. [**matplotlib.pyplot**](https://matplotlib.org/api/pyplot_api.html)
#
# 2. [**matplotlib.axes**](https://matplotlib.org/api/axes_api.html)
#
# 3. [**matplotlib.axes.Axes**](https://matplotlib.org/api/axes_api.html#the-axes-class)
#
# 4. [**matplotlib.pyplot.hist**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html)
#
# 5. [**matplotlib.pyplot.show**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.show.html)
#
# 6. [**matplotlib.axes.Axes.matshow**](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.matshow.html)
#
# 7. [**matplotlib.pyplot.subplots**](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.subplots.html)
#
# <br>
#
# ### [NumPy](http://www.numpy.org/)
#
# 1. [**numpy.random**](https://docs.scipy.org/doc/numpy/reference/routines.random.html)
#
# 2. [**numpy.random.permutation**](https://docs.scipy.org/doc/numpy/reference/generated/numpy.random.permutation.html)
#
# 3. [**numpy.ceil**](https://docs.scipy.org/doc/numpy/reference/generated/numpy.ceil.html)
#
# 4. [**numpy.asarray**](https://docs.scipy.org/doc/numpy/reference/generated/numpy.asarray.html)
#
# <br>
#
# ### [Scikit-Learn](https://scikit-learn.org/)
#
# 1. [**sklearn.model_selection**](https://scikit-learn.org/stable/model_selection.html)
#
# 2. [**sklearn.impute**](https://scikit-learn.org/stable/modules/impute.html)
#
# 3. [**sklearn.preprocessing**](https://scikit-learn.org/stable/modules/preprocessing.html)
#
# 4. [**sklearn.linear_model**](https://scikit-learn.org/stable/modules/linear_model.html)
#
# 5. [**sklearn.model_selection.train_test_split**](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html)
#
# 6. [**sklearn.model_selection.stratifiedShuffleSplit**](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.StratifiedShuffleSplit.html)
#
# 7. [**sklearn.impute.SimpleImputer**](https://scikit-learn.org/stable/modules/generated/sklearn.impute.SimpleImputer.html#sklearn.impute.SimpleImputer)
#
# 8. [**sklearn.preprocessing.OneHotEncoder**](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.OneHotEncoder.html)
#
# 9. [**sklearn.pipeline.Pipeline**](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html)
#
# 10. [**sklearn.pipeline.FeatureUnion**](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.FeatureUnion.html)
#
# 11. [**sklearn.linear_model.LinearRegression**](earn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
