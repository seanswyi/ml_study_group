# %% [markdown]
# # ML Study Group
#
# ##### March 4th, 2019 (Monday) 19:00 (GMT+9) @ Bitcoin Center Korea ([Meetup.com link](https://www.meetup.com/ml_study_group/events/259323184/))
#
# ## 1. Review last session and go through the technical details a bit more.
#
# ## 2. Introduction to linear regression.
#
# #### This session we'll be going over some details from last session (_Hands-On ML Chapter 2_) and also some concepts of linear regression. It's assumed that you have Python and the corresponding libraries installed, but if you don't then it shouldn't be hard to set up.
#
# <br>
#
# ![alt-text](https://github.com/seankala/ml_study_group/blob/master/Images/ML/homl_islr.jpg?raw=true)
#
# <br>
# <br>

# %% [markdown]
# ## List of Methods and Functions Used in Chapter 2
#
# ### [Pandas](https://pandas.pydata.org/)
#
# 1. [**pandas.read_csv()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
#
# 2. [**pandas.DataFrame.head()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.head.html)
#
# 3. [**pandas.DataFrame.info**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.info.html)
#
# 4. [**pandas.Series.value_counts**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.value_counts.html)
#
# 5. **pandas.DataFrame.describe**
#
# 6. **pandas.DataFrame.hist**
#
# 7. **pandas.DataFrame.loc**
#
# 8. **pandas.DataFrame.iloc**
#
# 9. **pandas.DataFrame.value_counts**
#
# 10. **pandas.DataFrame.sort_index**
#
# 11. **pandas.DataFrame.drop**
#
# 12. **pandas.DataFrame.corr**
#
# 13. **pandas.DataFrame.columns**
#
# 14. **pandas.plotting.scatter_matrix**
#
# 15. **pandas.DataFrame.sort_values**
#
# 16. **pandas.DataFrame.copy**
#
# 17. **pandas.DataFrame.dropna**
#
# 18. **pandas.DataFrame.fillna**
#
# 19. **pandas.DataFrame.isna**
#
# 20. **pandas.DataFrame.sum**
#
# 21. **pandas.DataFrame.median**
#
# <br>
#
# ### [Matplotlib](https://matplotlib.org/)
# matplotlib.pyplot.hist
# matplotlib.pyplot.show
# matplotlib.axes.Axes.matshow
# matplotlib.pyplot.subplots
#
# ### numpy
# numpy.random.permutation
# numpy.ceil
# numpy.asarray
#
# ### scikit-learn
# sklearn.model_selection.train_test_split
# sklearn.model_selection.stratifiedShuffleSplit
# sklearn.impute.SimpleImputer
# sklearn.preprocessing.OneHotEncoder
# sklearn.pipeline.Pipeline
# sklearn.pipeline.FeatureUnion
# sklearn.linear_model.LinearRegression
